# %%
from plip.structure.preparation import PDBComplex
from plip.exchange.webservices import loadSDF
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from plip.structure.preparation import PDBComplex
# ----> 2 from plip.exchange.webservices import loadSDF
#
# ImportError: cannot import name 'loadSDF' from 'plip.exchange.webservices' (/home/joe/Desktop/llchem/docking_images/plip/env/lib/python3.10/site-packages/plip/exchange/webservices.py)
